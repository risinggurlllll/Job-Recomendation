# %%
cd e:\work\Job-Recomendation
# Out:
# e:\work\Job-Recomendation

# %%
# importing the required modules
import glob
import pandas as pd
  
# specifying the path to csv files
path = "data\scrapped_data"
  
# csv files in the path
files = glob.glob(path + "/*.csv")
  
# defining an empty list to store 
# content
data_frame = pd.DataFrame()
content = []
count=0
# checking all the csv files in the 
# specified path
for filename in files:
    
    # reading content of csv file
    # content.append(filename)
    df = pd.read_csv(filename, index_col=None)
    content.append(df)
    count=count+1
  
# converting content to data frame
data_frame = pd.concat(content)
print("Total data frame -",count)
# Out:
# Total data frame - 11

# %%
data_frame=data_frame.drop(['companyLogo','id','jobType','scrapedAt'],axis=1)

# %%
data_frame.columns
# Out:
# Index(['company', 'description', 'externalApplyLink', 'location',
#        'positionName', 'postedAt', 'rating', 'reviewsCount', 'salary', 'url'],
#       dtype='object')

# %%
data_frame.columns
# Out:
# Index(['company', 'description', 'externalApplyLink', 'location',
#        'positionName', 'postedAt', 'rating', 'reviewsCount', 'salary', 'url'],
#       dtype='object')

# %%
df = data_frame.reindex(columns=['company','positionName','description','salary','location','rating','reviewsCount','postedAt','externalApplyLink','url'])

# %%
df
# Out:
#                        company  \
# 0                          IBM
# 1                          IBM
# 2                          IBM
# 3                          IBM
# 4                          IBM
# ..                         ...
# 495                         EY
# 496  JPMorgan Chase Bank, N.A.
# 497                  Accenture
# 498                        IBM
# 499                        IBM
#
#                                        positionName  \
# 0                        Application Developer: EAI
# 1      Application Developer: IBM Cloud Integration
# 2                                   Cloud Developer
# 3        Application Developer: Microsoft Analytics
# 4                     Software Developer: Microsoft
# ..                                              ...
# 495               Java_Full_stack_Backend Developer
# 496     FRDC-RDT-Accounts- Java Developer-Hyderabad
# 497                   ASP.NET Application Developer
# 498  Application Developer: SAP NextGen UX & Mobile
# 499                                 Cloud Developer
#
#                                            description salary  \
# 0    \r\n \r\n  Introduction\r\n   As an Applicatio...    NaN
# 1    \r\n \r\n  Introduction\r\n   As an Applicatio...    NaN
# 2    \r\n \r\n  Introduction\r\n   At IBM, work is ...    NaN
# 3    \r\n \r\n  Introduction\r\n   As an Applicatio...    NaN
# 4    \r\n \r\n  Introduction\r\n   \r\n  \r\n   In ...    NaN
# ..                                                 ...    ...
# 495  \r\n At EY, you’ll have the chance to build a ...    NaN
# 496  \r\n As a Software Engineer III at JPMorgan Ch...    NaN
# 497  \r\n About Accenture: Accenture is a global pr...    NaN
# 498  \r\n \r\n  Introduction\r\n   As an Applicatio...    NaN
# 499  \r\n \r\n  Introduction\r\n   At IBM, work is ...    NaN
#
#                    location  rating  reviewsCount   postedAt  \
# 0         Pune, Maharashtra     3.9       31981.0      Today
# 1      Bengaluru, Karnataka     3.9       31981.0      Today
# 2      Bengaluru, Karnataka     3.9       31981.0  1 day ago
# 3      Hyderabad, Telangana     3.9       31981.0      Today
# 4        Ahmedabad, Gujarat     3.9       31981.0  1 day ago
# ..                      ...     ...           ...        ...
# 495    Bengaluru, Karnataka     3.9        8726.0  1 day ago
# 496    Hyderabad, Telangana     3.9       18023.0  1 day ago
# 497  Coimbatore, Tamil Nadu     4.0       23070.0  1 day ago
# 498    Bengaluru, Karnataka     3.9       31981.0  1 day ago
# 499    Bengaluru, Karnataka     3.9       31981.0  1 day ago
#
#                                      externalApplyLink  \
# 0    https://in.indeed.com/applystart?jk=fb3f055a63...
# 1    https://in.indeed.com/applystart?jk=dcbc5cf465...
# 2    https://in.indeed.com/applystart?jk=6bc552083f...
# 3    https://in.indeed.com/applystart?jk=bf6cebfb33...
# 4    https://in.indeed.com/applystart?jk=b1b335e8ad...
# ..                                                 ...
# 495  https://in.indeed.com/applystart?jk=3a51e284cd...
# 496  https://in.indeed.com/applystart?jk=dd7e7fdfbe...
# 497  https://in.indeed.com/applystart?jk=ef3761755f...
# 498  https://in.indeed.com/applystart?jk=1e1e79f155...
# 499  https://in.indeed.com/applystart?jk=6bc552083f...
#
#                                                    url
# 0    https://www.indeed.co.in/rc/clk?jk=fb3f055a632...
# 1    https://www.indeed.co.in/rc/clk?jk=dcbc5cf4654...
# 2    https://www.indeed.co.in/rc/clk?jk=6bc552083f9...
# 3    https://www.indeed.co.in/rc/clk?jk=bf6cebfb333...
# 4    https://www.indeed.co.in/rc/clk?jk=b1b335e8ad3...
# ..                                                 ...
# 495  https://www.indeed.co.in/rc/clk?jk=3a51e284cd8...
# 496  https://www.indeed.co.in/rc/clk?jk=dd7e7fdfbe7...
# 497  https://www.indeed.co.in/rc/clk?jk=ef3761755fa...
# 498  https://www.indeed.co.in/rc/clk?jk=1e1e79f1550...
# 499  https://www.indeed.co.in/rc/clk?jk=6bc552083f9...
#
# [5502 rows x 10 columns]

# %%
df.to_csv("data.csv",index=False)
# Out:
# data.csv
